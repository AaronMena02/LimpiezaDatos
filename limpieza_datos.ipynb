# %% [markdown]
# # 1. Manejo de valores faltantes con NumPy

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("OrderLine_v4.csv", encoding = "latin1")

#He puesto replace porque con where me lo transforma en un array de numpy y me muestra el dataframe feo.
df.replace(0, np.nan, inplace=True)
data = np.array(df["productValue"])

nan_mask = np.isnan(data)  
print("¿Dónde hay valores NaN?:", nan_mask)

mean_value = np.nanmean(data) 
print("Media sin contar los NaN:", mean_value)

median_value = np.nanmedian(data)  
std_value = np.nanstd(data)  
print("Mediana:", median_value, "| Desviación estándar:", std_value)

# 3. np.where(cond, x, y) - Reemplazar valores NaN por la media
data_filled = np.where(np.isnan(data), mean_value, data)
print("Array con NaN reemplazados por la media:", data_filled)

# np.nan_to_num() - Reemplaza NaN con 0 (o un valor especificado)
data_zero_filled = np.nan_to_num(data, nan=0)
print("Array con NaN reemplazados por 0:", data_zero_filled)

# arr[~np.isnan(arr)] - Filtrar valores eliminando NaN
data_clean = data[~np.isnan(data)]
print("Array sin valores NaN:", data_clean)

df["productValueSinNulos"] = data_filled

df
# Out:
# ¿Dónde hay valores NaN?: [False  True  True False  True  True False  True  True False  True  True
#  False  True  True False  True  True False  True  True False  True  True
#  False  True  True False  True  True False  True  True False  True  True
#  False  True  True False  True  True False  True  True False  True  True
#  False  True  True False  True  True False  True  True False  True  True
#  False  True  True False  True  True False  True  True False  True  True
#  False  True  True False  True  True False  True  True False  True  True
#  False  True  True False  True  True False  True  True False  True  True
#  False  True  True False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True  True]
# Media sin contar los NaN: 483.7288732394366
# Mediana: 183.0 | Desviación estándar: 759.0938262518409
# Array con NaN reemplazados por la media: [1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+03
#  4.83728873e+02 4.83728873e+02 1.25000000e+03 4.83728873e+02
#  4.83728873e+02 1.25000000e+03 4.83728873e+02 4.83728873e+02
#  1.25000000e+03 4.83728873e+02 4.83728873e+02 1.25000000e+02
#  5.50000000e+01 4.80000000e+01 2.89000000e+02 1.83000000e+02
#  2.89000000e+02 1.83000000e+02 1.25000000e+02 5.50000000e+01
#  4.80000000e+01 2.89000000e+02 1.83000000e+02 2.89000000e+02
#  1.83000000e+02 1.25000000e+02 5.50000000e+01 4.80000000e+01
#  5.10000000e+01 7.80000000e+01 8.80000000e+01 9.30000000e+01
#  1.83000000e+02 2.89000000e+02 1.83000000e+02 1.25000000e+02
#  5.50000000e+01 4.80000000e+01 2.89000000e+02 1.83000000e+02
#  2.89000000e+02 1.83000000e+02 1.25000000e+02 5.50000000e+01
#  1.25000000e+02 5.50000000e+01 4.80000000e+01 2.89000000e+02
#  5.50000000e+01 2.89000000e+02 1.83000000e+02 1.25000000e+02
#  5.10000000e+01 2.89000000e+02 1.83000000e+02 1.25000000e+02
#  5.10000000e+01 2.89000000e+02 1.83000000e+02 1.25000000e+02
#  5.10000000e+01 2.89000000e+02 1.83000000e+02 1.25000000e+02
#  5.10000000e+01 2.89000000e+02 1.83000000e+02 1.25000000e+02
#  5.10000000e+01 2.89000000e+02 1.83000000e+02 1.25000000e+02
#  5.10000000e+01 5.50000000e+01 7.80000000e+01 9.30000000e+01
#  8.80000000e+01 5.50000000e+01 7.80000000e+01 9.30000000e+01
#  8.80000000e+01 5.50000000e+01 7.80000000e+01 9.30000000e+01
#  8.80000000e+01 5.50000000e+01 7.80000000e+01 9.30000000e+01
#  8.80000000e+01 5.50000000e+01 7.80000000e+01 9.30000000e+01
#  8.80000000e+01 5.50000000e+01 7.80000000e+01 9.30000000e+01
#  8.80000000e+01 3.00000000e+00 4.55000000e+02 4.55000000e+02
#  1.90000000e+01 5.00000000e+00 9.90000000e+02 2.39800000e+03
#  2.39800000e+03 3.00000000e+00 4.55000000e+02 1.90000000e+01
#  4.12000000e+02 3.00000000e+00 5.50000000e+01 5.50000000e+01
#  1.08000000e+02 2.03000000e+02 1.22000000e+02 5.50000000e+01
#  3.00000000e+00 5.00000000e+00 5.00000000e+00 5.50000000e+01
#  1.220e+02 1.900e+01 4.220e+02 4.120e+02 4.550e+02 4.120e+02 3.000e+00
#  1.220e+02 1.032e+03 3.000e+00 5.500e+01 1.890e+02 5.000e+00 2.400e+01
#  4.550e+02 2.030e+02 1.220e+02 1.120e+02 2.398e+03 3.500e+02 3.500e+02
#  1.287e+03 1.080e+02 5.000e+00 7.740e+02 3.500e+02 3.500e+02 3.000e+00
#  5.500e+01 5.000e+01 1.120e+02 2.030e+02 5.000e+01 8.330e+02 3.000e+00
#  5.500e+01 5.500e+01 8.330e+02 5.500e+01 4.120e+02 2.400e+01 5.500e+01
#  1.220e+02 1.080e+02 5.500e+01 2.400e+01 4.120e+02 3.000e+00 1.180e+03
#  1.452e+03 3.000e+00 3.500e+02 1.900e+01 2.400e+01 9.760e+02 3.500e+02
#  9.900e+02 2.400e+01 1.287e+03 4.592e+03 1.290e+03 9.500e+02 3.500e+02
#  5.000e+01 3.000e+00 1.180e+03 1.250e+03]
#      orderIdentifier  orderLineNumber orderType product.partNumber  \
# 0          100044323              100  OUTBOUND         PS-SL-B122
# 1          100044323              200  OUTBOUND          PS-SL-KIT
# 2          100044323              300  OUTBOUND         PS-SL-INFO
# 3          100044324              100  OUTBOUND         PS-SL-F343
# 4          100044324              200  OUTBOUND          PS-SL-KIT
# ..               ...              ...       ...                ...
# 347       1000567497              100   INBOUND            9665306
# 348       1000567500              100   INBOUND            2530020
# 349        100044322              100  OUTBOUND         PS-SL-A287
# 350        100044322              200  OUTBOUND          PS-SL-KIT
# 351        100044322              300  OUTBOUND         PS-SL-INFO
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-2
# 1                                             LT-2
# 2                                             LT-2
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 347                           Interalloy - Bozeman
# 348                           McGrey - Mt Sterling
# 349                                           LT-2
# 350                                           LT-2
# 351                                           LT-2
#
#     shipToLocation.locationIdentifier  status          createdDate  \
# 0                    FAA - Washington     NaN  2021-07-20T00:00:00
# 1                    FAA - Washington     NaN  2021-07-20T00:00:00
# 2                    FAA - Washington     NaN  2021-07-20T00:00:00
# 3                    FAA - Washington     NaN  2021-07-20T00:00:00
# 4                    FAA - Washington     NaN  2021-07-20T00:00:00
# ..                                ...     ...                  ...
# 347                              LT-1     NaN  2021-07-15T00:00:00
# 348                              LT-1     NaN  2021-07-08T00:00:00
# 349                  FAA - Washington     NaN  2017-07-20T00:00:00
# 350                  FAA - Washington     NaN  2017-07-20T00:00:00
# 351                  FAA - Washington     NaN  2017-07-20T00:00:00
#
#        requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 0    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 1    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 2    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 3    2021-08-19T00:00:00   2021-08-22T00:00:00  2021-08-19T00:00:00
# 4    2021-08-19T00:00:00   2021-08-22T00:00:00  2021-08-19T00:00:00
# ..                   ...                   ...                  ...
# 347  2021-07-26T00:00:00   2021-07-26T00:00:00  2021-07-21T00:00:00
# 348  2021-07-19T00:00:00   2021-07-19T00:00:00  2021-07-15T00:00:00
# 349  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
# 350  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
# 351  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
#
#      plannedDeliveryDate  quantity quantityUnits  productValue     value  \
# 0    2021-09-06T00:00:00       250            EA        1250.0  312500.0
# 1    2021-09-06T00:00:00       250            EA           NaN       NaN
# 2    2021-09-06T00:00:00       250            EA           NaN       NaN
# 3    2021-08-22T00:00:00       132            EA        1250.0  165000.0
# 4    2021-08-22T00:00:00       132            EA           NaN       NaN
# ..                   ...       ...           ...           ...       ...
# 347                  NaN        44            EA           3.0     132.0
# 348  2021-07-19T00:00:00        56            EA        1180.0   66080.0
# 349  2021-08-14T00:00:00       400            EA        1250.0  500000.0
# 350  2021-08-14T00:00:00       400            EA           NaN       NaN
# 351  2021-08-14T00:00:00       400            EA           NaN       NaN
#
#     valueCurrency  shipmentCount  productValueSinNulos
# 0             USD            NaN           1250.000000
# 1             USD            NaN            483.728873
# 2             USD            NaN            483.728873
# 3             USD            NaN           1250.000000
# 4             USD            NaN            483.728873
# ..            ...            ...                   ...
# 347           USD            NaN              3.000000
# 348           USD            NaN           1180.000000
# 349           USD            NaN           1250.000000
# 350           USD            NaN            483.728873
# 351           USD            NaN            483.728873
#
# [352 rows x 19 columns]

# %% [markdown]
# # 2. Manejo de valores faltantes con Pandas

# %%
import pandas as pd
import numpy as np

#Leer el archivo CSV
df = pd.read_csv("OrderLine_v4.csv", encoding="latin1")

#Reemplazar ceros por NaN
df.replace(0, np.nan, inplace=True)

#Detectar valores NaN
print("¿Dónde hay valores NaN?")
print(df.isna())  # Devuelve True donde hay NaN y False donde hay datos

#Eliminar filas con valores NaN
df_dropped = df.dropna()
print("\nDataFrame después de eliminar filas con NaN:")
print(df_dropped)

#Eliminar columnas con NaN usando axis=1
df_dropped_cols = df.dropna(axis=1)
print("\nDataFrame después de eliminar columnas con NaN:")
print(df_dropped_cols)


#Rellenar NaN con la media
df["productValueSinNulos_pandas_mean"] = df["productValue"].fillna(df["productValue"].mean())

#Rellenar NaN con la mediana
df["productValueSinNulos_pandas_median"] = df["productValue"].fillna(df["productValue"].median())

#Rellenar NaN con la moda
df["productValueSinNulos_pandas_mode"] = df["productValue"].fillna(df["productValue"].mode().iloc[0])

#Rellenar NaN con el último valor válido (Forward Fill)
df["productValueSinNulos_pandas_ffill"] = df["productValue"].fillna(method="ffill")

#Rellenar NaN con el siguiente valor válido (Backward Fill)
df["productValueSinNulos_pandas_bfill"] = df["productValue"].fillna(method="bfill")

df
# Out:
# ¿Dónde hay valores NaN?
#      orderIdentifier  orderLineNumber  orderType  product.partNumber  \
# 0              False            False      False               False
# 1              False            False      False               False
# 2              False            False      False               False
# 3              False            False      False               False
# 4              False            False      False               False
# ..               ...              ...        ...                 ...
# 347            False            False      False               False
# 348            False            False      False               False
# 349            False            False      False               False
# 350            False            False      False               False
# 351            False            False      False               False
#
#      shipFromInstructionLocation.locationIdentifier  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ..                                              ...
# 347                                           False
# 348                                           False
# 349                                           False
# 350                                           False
# 351                                           False
#
#      shipToLocation.locationIdentifier  status  createdDate  \
# 0                                False    True        False
# 1                                False    True        False
# 2                                False    True        False
# 3                                False    True        False
# 4                                False    True        False
# ..                                 ...     ...          ...
# 347                              False    True        False
# 348                              False    True        False
# 349                              False    True        False
# 350                              False    True        False
# 351                              False    True        False
#
#      requestedShipDate  requestedDeliveryDate  plannedShipDate  \
# 0                False                  False            False
# 1                False                  False            False
# 2                False                  False            False
# 3                False                  False            False
# 4                False                  False            False
# ..                 ...                    ...              ...
# 347              False                  False            False
# 348              False                  False            False
# 349              False                  False            False
# 350              False                  False            False
# 351              False                  False            False
#
#      plannedDeliveryDate  quantity  quantityUnits  productValue  value  \
# 0                  False     False          False         False  False
# 1                  False     False          False          True   True
# 2                  False     False          False          True   True
# 3                  False     False          False         False  False
# 4                  False     False          False          True   True
# ..                   ...       ...            ...           ...    ...
# 347                 True     False          False         False  False
# 348                False     False          False         False  False
# 349                False     False          False         False  False
# 350                False     False          False          True   True
# 351                False     False          False          True   True
#
#      valueCurrency  shipmentCount
# 0            False           True
# 1            False           True
# 2            False           True
# 3            False           True
# 4            False           True
# ..             ...            ...
# 347          False           True
# 348          False           True
# 349          False           True
# 350          False           True
# 351          False           True
#
# [352 rows x 18 columns]
#
# DataFrame después de eliminar filas con NaN:
# Empty DataFrame
# Columns: [orderIdentifier, orderLineNumber, orderType, product.partNumber, shipFromInstructionLocation.locationIdentifier, shipToLocation.locationIdentifier, status, createdDate, requestedShipDate, requestedDeliveryDate, plannedShipDate, plannedDeliveryDate, quantity, quantityUnits, productValue, value, valueCurrency, shipmentCount]
# Index: []
#
# DataFrame después de eliminar columnas con NaN:
#      orderIdentifier  orderLineNumber orderType product.partNumber  \
# 0          100044323              100  OUTBOUND         PS-SL-B122
# 1          100044323              200  OUTBOUND          PS-SL-KIT
# 2          100044323              300  OUTBOUND         PS-SL-INFO
# 3          100044324              100  OUTBOUND         PS-SL-F343
# 4          100044324              200  OUTBOUND          PS-SL-KIT
# ..               ...              ...       ...                ...
# 347       1000567497              100   INBOUND            9665306
# 348       1000567500              100   INBOUND            2530020
# 349        100044322              100  OUTBOUND         PS-SL-A287
# 350        100044322              200  OUTBOUND          PS-SL-KIT
# 351        100044322              300  OUTBOUND         PS-SL-INFO
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-2
# 1                                             LT-2
# 2                                             LT-2
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 347                           Interalloy - Bozeman
# 348                           McGrey - Mt Sterling
# 349                                           LT-2
# 350                                           LT-2
# 351                                           LT-2
#
#     shipToLocation.locationIdentifier          createdDate  \
# 0                    FAA - Washington  2021-07-20T00:00:00
# 1                    FAA - Washington  2021-07-20T00:00:00
# 2                    FAA - Washington  2021-07-20T00:00:00
# 3                    FAA - Washington  2021-07-20T00:00:00
# 4                    FAA - Washington  2021-07-20T00:00:00
# ..                                ...                  ...
# 347                              LT-1  2021-07-15T00:00:00
# 348                              LT-1  2021-07-08T00:00:00
# 349                  FAA - Washington  2017-07-20T00:00:00
# 350                  FAA - Washington  2017-07-20T00:00:00
# 351                  FAA - Washington  2017-07-20T00:00:00
#
#        requestedShipDate requestedDeliveryDate  quantity quantityUnits  \
# 0    2021-08-31T00:00:00   2021-09-06T00:00:00       250            EA
# 1    2021-08-31T00:00:00   2021-09-06T00:00:00       250            EA
# 2    2021-08-31T00:00:00   2021-09-06T00:00:00       250            EA
# 3    2021-08-19T00:00:00   2021-08-22T00:00:00       132            EA
# 4    2021-08-19T00:00:00   2021-08-22T00:00:00       132            EA
# ..                   ...                   ...       ...           ...
# 347  2021-07-26T00:00:00   2021-07-26T00:00:00        44            EA
# 348  2021-07-19T00:00:00   2021-07-19T00:00:00        56            EA
# 349  2021-08-11T00:00:00   2021-08-14T00:00:00       400            EA
# 350  2021-08-11T00:00:00   2021-08-14T00:00:00       400            EA
# 351  2021-08-11T00:00:00   2021-08-14T00:00:00       400            EA
#
#     valueCurrency
# 0             USD
# 1             USD
# 2             USD
# 3             USD
# 4             USD
# ..            ...
# 347           USD
# 348           USD
# 349           USD
# 350           USD
# 351           USD
#
# [352 rows x 12 columns]
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14788\1012181422.py:36: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["productValueSinNulos_pandas_ffill"] = df["productValue"].fillna(method="ffill")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14788\1012181422.py:39: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["productValueSinNulos_pandas_bfill"] = df["productValue"].fillna(method="bfill")
#      orderIdentifier  orderLineNumber orderType product.partNumber  \
# 0          100044323              100  OUTBOUND         PS-SL-B122
# 1          100044323              200  OUTBOUND          PS-SL-KIT
# 2          100044323              300  OUTBOUND         PS-SL-INFO
# 3          100044324              100  OUTBOUND         PS-SL-F343
# 4          100044324              200  OUTBOUND          PS-SL-KIT
# ..               ...              ...       ...                ...
# 347       1000567497              100   INBOUND            9665306
# 348       1000567500              100   INBOUND            2530020
# 349        100044322              100  OUTBOUND         PS-SL-A287
# 350        100044322              200  OUTBOUND          PS-SL-KIT
# 351        100044322              300  OUTBOUND         PS-SL-INFO
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-2
# 1                                             LT-2
# 2                                             LT-2
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 347                           Interalloy - Bozeman
# 348                           McGrey - Mt Sterling
# 349                                           LT-2
# 350                                           LT-2
# 351                                           LT-2
#
#     shipToLocation.locationIdentifier  status          createdDate  \
# 0                    FAA - Washington     NaN  2021-07-20T00:00:00
# 1                    FAA - Washington     NaN  2021-07-20T00:00:00
# 2                    FAA - Washington     NaN  2021-07-20T00:00:00
# 3                    FAA - Washington     NaN  2021-07-20T00:00:00
# 4                    FAA - Washington     NaN  2021-07-20T00:00:00
# ..                                ...     ...                  ...
# 347                              LT-1     NaN  2021-07-15T00:00:00
# 348                              LT-1     NaN  2021-07-08T00:00:00
# 349                  FAA - Washington     NaN  2017-07-20T00:00:00
# 350                  FAA - Washington     NaN  2017-07-20T00:00:00
# 351                  FAA - Washington     NaN  2017-07-20T00:00:00
#
#        requestedShipDate requestedDeliveryDate  ... quantityUnits  \
# 0    2021-08-31T00:00:00   2021-09-06T00:00:00  ...            EA
# 1    2021-08-31T00:00:00   2021-09-06T00:00:00  ...            EA
# 2    2021-08-31T00:00:00   2021-09-06T00:00:00  ...            EA
# 3    2021-08-19T00:00:00   2021-08-22T00:00:00  ...            EA
# 4    2021-08-19T00:00:00   2021-08-22T00:00:00  ...            EA
# ..                   ...                   ...  ...           ...
# 347  2021-07-26T00:00:00   2021-07-26T00:00:00  ...            EA
# 348  2021-07-19T00:00:00   2021-07-19T00:00:00  ...            EA
# 349  2021-08-11T00:00:00   2021-08-14T00:00:00  ...            EA
# 350  2021-08-11T00:00:00   2021-08-14T00:00:00  ...            EA
# 351  2021-08-11T00:00:00   2021-08-14T00:00:00  ...            EA
#
#     productValue     value valueCurrency  shipmentCount  \
# 0         1250.0  312500.0           USD            NaN
# 1            NaN       NaN           USD            NaN
# 2            NaN       NaN           USD            NaN
# 3         1250.0  165000.0           USD            NaN
# 4            NaN       NaN           USD            NaN
# ..           ...       ...           ...            ...
# 347          3.0     132.0           USD            NaN
# 348       1180.0   66080.0           USD            NaN
# 349       1250.0  500000.0           USD            NaN
# 350          NaN       NaN           USD            NaN
# 351          NaN       NaN           USD            NaN
#
#      productValueSinNulos_pandas_mean productValueSinNulos_pandas_median  \
# 0                         1250.000000                             1250.0
# 1                          483.728873                              183.0
# 2                          483.728873                              183.0
# 3                         1250.000000                             1250.0
# 4                          483.728873                              183.0
# ..                                ...                                ...
# 347                          3.000000                                3.0
# 348                       1180.000000                             1180.0
# 349                       1250.000000                             1250.0
# 350                        483.728873                              183.0
# 351                        483.728873                              183.0
#
#      productValueSinNulos_pandas_mode  productValueSinNulos_pandas_ffill  \
# 0                              1250.0                             1250.0
# 1                              1250.0                             1250.0
# 2                              1250.0                             1250.0
# 3                              1250.0                             1250.0
# 4                              1250.0                             1250.0
# ..                                ...                                ...
# 347                               3.0                                3.0
# 348                            1180.0                             1180.0
# 349                            1250.0                             1250.0
# 350                            1250.0                             1250.0
# 351                            1250.0                             1250.0
#
#      productValueSinNulos_pandas_bfill
# 0                               1250.0
# 1                               1250.0
# 2                               1250.0
# 3                               1250.0
# 4                               1250.0
# ..                                 ...
# 347                                3.0
# 348                             1180.0
# 349                             1250.0
# 350                                NaN
# 351                                NaN
#
# [352 rows x 23 columns]

# %% [markdown]
# # 3. Manejo de valores faltantes con Scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# Leer el archivo CSV
df = pd.read_csv("OrderLine_v4.csv", encoding="latin1")

# Reemplazar ceros por NaN
df.replace(0, np.nan, inplace=True)

# Extraer solo la columna "productValue" para imputación
product_value = df[["productValue"]]

# Detectar valores NaN en la columna
print("\n¿Dónde hay valores NaN en 'productValue'?:")
print(product_value.isna())

# Rellenar NaN con la media usando Scikit-learn
imputer_mean = SimpleImputer(strategy="mean")  
df["productValueSinNulos_sklearn_mean"] = imputer_mean.fit_transform(product_value)

print("\nDataFrame con NaN reemplazados por la media usando Scikit-learn:")
print(df)

# Rellenar NaN con la mediana
imputer_median = SimpleImputer(strategy="median")
df["productValueSinNulos_sklearn_median"] = imputer_median.fit_transform(product_value)

print("\nDataFrame con NaN reemplazados por la mediana usando Scikit-learn:")
print(df)

# Rellenar NaN con la moda
imputer_mode = SimpleImputer(strategy="most_frequent")
df["productValueSinNulos_sklearn_mode"] = imputer_mode.fit_transform(product_value)

print("\nDataFrame con NaN reemplazados por la moda usando Scikit-learn:")
print(df)

# Rellenar NaN con un valor constante (ejemplo: 0)
imputer_const = SimpleImputer(strategy="constant", fill_value=0)
df["productValueSinNulos_sklearn_const"] = imputer_const.fit_transform(product_value)

print("\nDataFrame con NaN reemplazados por un valor constante usando Scikit-learn:")
df
# Out:
# ¿Dónde hay valores NaN en 'productValue'?:
#      productValue
# 0           False
# 1            True
# 2            True
# 3           False
# 4            True
# ..            ...
# 347         False
# 348         False
# 349         False
# 350          True
# 351          True
#
# [352 rows x 1 columns]
#
# DataFrame con NaN reemplazados por la media usando Scikit-learn:
#      orderIdentifier  orderLineNumber orderType product.partNumber  \
# 0          100044323              100  OUTBOUND         PS-SL-B122
# 1          100044323              200  OUTBOUND          PS-SL-KIT
# 2          100044323              300  OUTBOUND         PS-SL-INFO
# 3          100044324              100  OUTBOUND         PS-SL-F343
# 4          100044324              200  OUTBOUND          PS-SL-KIT
# ..               ...              ...       ...                ...
# 347       1000567497              100   INBOUND            9665306
# 348       1000567500              100   INBOUND            2530020
# 349        100044322              100  OUTBOUND         PS-SL-A287
# 350        100044322              200  OUTBOUND          PS-SL-KIT
# 351        100044322              300  OUTBOUND         PS-SL-INFO
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-2
# 1                                             LT-2
# 2                                             LT-2
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 347                           Interalloy - Bozeman
# 348                           McGrey - Mt Sterling
# 349                                           LT-2
# 350                                           LT-2
# 351                                           LT-2
#
#     shipToLocation.locationIdentifier  status          createdDate  \
# 0                    FAA - Washington     NaN  2021-07-20T00:00:00
# 1                    FAA - Washington     NaN  2021-07-20T00:00:00
# 2                    FAA - Washington     NaN  2021-07-20T00:00:00
# 3                    FAA - Washington     NaN  2021-07-20T00:00:00
# 4                    FAA - Washington     NaN  2021-07-20T00:00:00
# ..                                ...     ...                  ...
# 347                              LT-1     NaN  2021-07-15T00:00:00
# 348                              LT-1     NaN  2021-07-08T00:00:00
# 349                  FAA - Washington     NaN  2017-07-20T00:00:00
# 350                  FAA - Washington     NaN  2017-07-20T00:00:00
# 351                  FAA - Washington     NaN  2017-07-20T00:00:00
#
#        requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 0    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 1    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 2    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 3    2021-08-19T00:00:00   2021-08-22T00:00:00  2021-08-19T00:00:00
# 4    2021-08-19T00:00:00   2021-08-22T00:00:00  2021-08-19T00:00:00
# ..                   ...                   ...                  ...
# 347  2021-07-26T00:00:00   2021-07-26T00:00:00  2021-07-21T00:00:00
# 348  2021-07-19T00:00:00   2021-07-19T00:00:00  2021-07-15T00:00:00
# 349  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
# 350  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
# 351  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
#
#      plannedDeliveryDate  quantity quantityUnits  productValue     value  \
# 0    2021-09-06T00:00:00       250            EA        1250.0  312500.0
# 1    2021-09-06T00:00:00       250            EA           NaN       NaN
# 2    2021-09-06T00:00:00       250            EA           NaN       NaN
# 3    2021-08-22T00:00:00       132            EA        1250.0  165000.0
# 4    2021-08-22T00:00:00       132            EA           NaN       NaN
# ..                   ...       ...           ...           ...       ...
# 347                  NaN        44            EA           3.0     132.0
# 348  2021-07-19T00:00:00        56            EA        1180.0   66080.0
# 349  2021-08-14T00:00:00       400            EA        1250.0  500000.0
# 350  2021-08-14T00:00:00       400            EA           NaN       NaN
# 351  2021-08-14T00:00:00       400            EA           NaN       NaN
#
#     valueCurrency  shipmentCount  productValueSinNulos_sklearn_mean
# 0             USD            NaN                        1250.000000
# 1             USD            NaN                         483.728873
# 2             USD            NaN                         483.728873
# 3             USD            NaN                        1250.000000
# 4             USD            NaN                         483.728873
# ..            ...            ...                                ...
# 347           USD            NaN                           3.000000
# 348           USD            NaN                        1180.000000
# 349           USD            NaN                        1250.000000
# 350           USD            NaN                         483.728873
# 351           USD            NaN                         483.728873
#
# [352 rows x 19 columns]
#
# DataFrame con NaN reemplazados por la mediana usando Scikit-learn:
#      orderIdentifier  orderLineNumber orderType product.partNumber  \
# 0          100044323              100  OUTBOUND         PS-SL-B122
# 1          100044323              200  OUTBOUND          PS-SL-KIT
# 2          100044323              300  OUTBOUND         PS-SL-INFO
# 3          100044324              100  OUTBOUND         PS-SL-F343
# 4          100044324              200  OUTBOUND          PS-SL-KIT
# ..               ...              ...       ...                ...
# 347       1000567497              100   INBOUND            9665306
# 348       1000567500              100   INBOUND            2530020
# 349        100044322              100  OUTBOUND         PS-SL-A287
# 350        100044322              200  OUTBOUND          PS-SL-KIT
# 351        100044322              300  OUTBOUND         PS-SL-INFO
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-2
# 1                                             LT-2
# 2                                             LT-2
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 347                           Interalloy - Bozeman
# 348                           McGrey - Mt Sterling
# 349                                           LT-2
# 350                                           LT-2
# 351                                           LT-2
#
#     shipToLocation.locationIdentifier  status          createdDate  \
# 0                    FAA - Washington     NaN  2021-07-20T00:00:00
# 1                    FAA - Washington     NaN  2021-07-20T00:00:00
# 2                    FAA - Washington     NaN  2021-07-20T00:00:00
# 3                    FAA - Washington     NaN  2021-07-20T00:00:00
# 4                    FAA - Washington     NaN  2021-07-20T00:00:00
# ..                                ...     ...                  ...
# 347                              LT-1     NaN  2021-07-15T00:00:00
# 348                              LT-1     NaN  2021-07-08T00:00:00
# 349                  FAA - Washington     NaN  2017-07-20T00:00:00
# 350                  FAA - Washington     NaN  2017-07-20T00:00:00
# 351                  FAA - Washington     NaN  2017-07-20T00:00:00
#
#        requestedShipDate requestedDeliveryDate      plannedShipDate  \
# 0    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 1    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 2    2021-08-31T00:00:00   2021-09-06T00:00:00  2021-09-03T00:00:00
# 3    2021-08-19T00:00:00   2021-08-22T00:00:00  2021-08-19T00:00:00
# 4    2021-08-19T00:00:00   2021-08-22T00:00:00  2021-08-19T00:00:00
# ..                   ...                   ...                  ...
# 347  2021-07-26T00:00:00   2021-07-26T00:00:00  2021-07-21T00:00:00
# 348  2021-07-19T00:00:00   2021-07-19T00:00:00  2021-07-15T00:00:00
# 349  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
# 350  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
# 351  2021-08-11T00:00:00   2021-08-14T00:00:00  2021-08-11T00:00:00
#
#      plannedDeliveryDate  quantity quantityUnits  productValue     value  \
# 0    2021-09-06T00:00:00       250            EA        1250.0  312500.0
# 1    2021-09-06T00:00:00       250            EA           NaN       NaN
# 2    2021-09-06T00:00:00       250            EA           NaN       NaN
# 3    2021-08-22T00:00:00       132            EA        1250.0  165000.0
# 4    2021-08-22T00:00:00       132            EA           NaN       NaN
# ..                   ...       ...           ...           ...       ...
# 347                  NaN        44            EA           3.0     132.0
# 348  2021-07-19T00:00:00        56            EA        1180.0   66080.0
# 349  2021-08-14T00:00:00       400            EA        1250.0  500000.0
# 350  2021-08-14T00:00:00       400            EA           NaN       NaN
# 351  2021-08-14T00:00:00       400            EA           NaN       NaN
#
#     valueCurrency  shipmentCount  productValueSinNulos_sklearn_mean  \
# 0             USD            NaN                        1250.000000
# 1             USD            NaN                         483.728873
# 2             USD            NaN                         483.728873
# 3             USD            NaN                        1250.000000
# 4             USD            NaN                         483.728873
# ..            ...            ...                                ...
# 347           USD            NaN                           3.000000
# 348           USD            NaN                        1180.000000
# 349           USD            NaN                        1250.000000
# 350           USD            NaN                         483.728873
# 351           USD            NaN                         483.728873
#
#      productValueSinNulos_sklearn_median
# 0                                 1250.0
# 1                                  183.0
# 2                                  183.0
# 3                                 1250.0
# 4                                  183.0
# ..                                   ...
# 347                                  3.0
# 348                               1180.0
# 349                               1250.0
# 350                                183.0
# 351                                183.0
#
# [352 rows x 20 columns]
#
# DataFrame con NaN reemplazados por la moda usando Scikit-learn:
#      orderIdentifier  orderLineNumber orderType product.partNumber  \
# 0          100044323              100  OUTBOUND         PS-SL-B122
# 1          100044323              200  OUTBOUND          PS-SL-KIT
# 2          100044323              300  OUTBOUND         PS-SL-INFO
# 3          100044324              100  OUTBOUND         PS-SL-F343
# 4          100044324              200  OUTBOUND          PS-SL-KIT
# ..               ...              ...       ...                ...
# 347       1000567497              100   INBOUND            9665306
# 348       1000567500              100   INBOUND            2530020
# 349        100044322              100  OUTBOUND         PS-SL-A287
# 350        100044322              200  OUTBOUND          PS-SL-KIT
# 351        100044322              300  OUTBOUND         PS-SL-INFO
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-2
# 1                                             LT-2
# 2                                             LT-2
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 347                           Interalloy - Bozeman
# 348                           McGrey - Mt Sterling
# 349                                           LT-2
# 350                                           LT-2
# 351                                           LT-2
#
#     shipToLocation.locationIdentifier  status          createdDate  \
# 0                    FAA - Washington     NaN  2021-07-20T00:00:00
# 1                    FAA - Washington     NaN  2021-07-20T00:00:00
# 2                    FAA - Washington     NaN  2021-07-20T00:00:00
# 3                    FAA - Washington     NaN  2021-07-20T00:00:00
# 4                    FAA - Washington     NaN  2021-07-20T00:00:00
# ..                                ...     ...                  ...
# 347                              LT-1     NaN  2021-07-15T00:00:00
# 348                              LT-1     NaN  2021-07-08T00:00:00
# 349                  FAA - Washington     NaN  2017-07-20T00:00:00
# 350                  FAA - Washington     NaN  2017-07-20T00:00:00
# 351                  FAA - Washington     NaN  2017-07-20T00:00:00
#
#        requestedShipDate requestedDeliveryDate  ...  plannedDeliveryDate  \
# 0    2021-08-31T00:00:00   2021-09-06T00:00:00  ...  2021-09-06T00:00:00
# 1    2021-08-31T00:00:00   2021-09-06T00:00:00  ...  2021-09-06T00:00:00
# 2    2021-08-31T00:00:00   2021-09-06T00:00:00  ...  2021-09-06T00:00:00
# 3    2021-08-19T00:00:00   2021-08-22T00:00:00  ...  2021-08-22T00:00:00
# 4    2021-08-19T00:00:00   2021-08-22T00:00:00  ...  2021-08-22T00:00:00
# ..                   ...                   ...  ...                  ...
# 347  2021-07-26T00:00:00   2021-07-26T00:00:00  ...                  NaN
# 348  2021-07-19T00:00:00   2021-07-19T00:00:00  ...  2021-07-19T00:00:00
# 349  2021-08-11T00:00:00   2021-08-14T00:00:00  ...  2021-08-14T00:00:00
# 350  2021-08-11T00:00:00   2021-08-14T00:00:00  ...  2021-08-14T00:00:00
# 351  2021-08-11T00:00:00   2021-08-14T00:00:00  ...  2021-08-14T00:00:00
#
#     quantity  quantityUnits productValue     value  valueCurrency  \
# 0        250             EA       1250.0  312500.0            USD
# 1        250             EA          NaN       NaN            USD
# 2        250             EA          NaN       NaN            USD
# 3        132             EA       1250.0  165000.0            USD
# 4        132             EA          NaN       NaN            USD
# ..       ...            ...          ...       ...            ...
# 347       44             EA          3.0     132.0            USD
# 348       56             EA       1180.0   66080.0            USD
# 349      400             EA       1250.0  500000.0            USD
# 350      400             EA          NaN       NaN            USD
# 351      400             EA          NaN       NaN            USD
#
#     shipmentCount  productValueSinNulos_sklearn_mean  \
# 0             NaN                        1250.000000
# 1             NaN                         483.728873
# 2             NaN                         483.728873
# 3             NaN                        1250.000000
# 4             NaN                         483.728873
# ..            ...                                ...
# 347           NaN                           3.000000
# 348           NaN                        1180.000000
# 349           NaN                        1250.000000
# 350           NaN                         483.728873
# 351           NaN                         483.728873
#
#      productValueSinNulos_sklearn_median  productValueSinNulos_sklearn_mode
# 0                                 1250.0                             1250.0
# 1                                  183.0                             1250.0
# 2                                  183.0                             1250.0
# 3                                 1250.0                             1250.0
# 4                                  183.0                             1250.0
# ..                                   ...                                ...
# 347                                  3.0                                3.0
# 348                               1180.0                             1180.0
# 349                               1250.0                             1250.0
# 350                                183.0                             1250.0
# 351                                183.0                             1250.0
#
# [352 rows x 21 columns]
#
# DataFrame con NaN reemplazados por un valor constante usando Scikit-learn:
#      orderIdentifier  orderLineNumber orderType product.partNumber  \
# 0          100044323              100  OUTBOUND         PS-SL-B122
# 1          100044323              200  OUTBOUND          PS-SL-KIT
# 2          100044323              300  OUTBOUND         PS-SL-INFO
# 3          100044324              100  OUTBOUND         PS-SL-F343
# 4          100044324              200  OUTBOUND          PS-SL-KIT
# ..               ...              ...       ...                ...
# 347       1000567497              100   INBOUND            9665306
# 348       1000567500              100   INBOUND            2530020
# 349        100044322              100  OUTBOUND         PS-SL-A287
# 350        100044322              200  OUTBOUND          PS-SL-KIT
# 351        100044322              300  OUTBOUND         PS-SL-INFO
#
#     shipFromInstructionLocation.locationIdentifier  \
# 0                                             LT-2
# 1                                             LT-2
# 2                                             LT-2
# 3                                             LT-2
# 4                                             LT-2
# ..                                             ...
# 347                           Interalloy - Bozeman
# 348                           McGrey - Mt Sterling
# 349                                           LT-2
# 350                                           LT-2
# 351                                           LT-2
#
#     shipToLocation.locationIdentifier  status          createdDate  \
# 0                    FAA - Washington     NaN  2021-07-20T00:00:00
# 1                    FAA - Washington     NaN  2021-07-20T00:00:00
# 2                    FAA - Washington     NaN  2021-07-20T00:00:00
# 3                    FAA - Washington     NaN  2021-07-20T00:00:00
# 4                    FAA - Washington     NaN  2021-07-20T00:00:00
# ..                                ...     ...                  ...
# 347                              LT-1     NaN  2021-07-15T00:00:00
# 348                              LT-1     NaN  2021-07-08T00:00:00
# 349                  FAA - Washington     NaN  2017-07-20T00:00:00
# 350                  FAA - Washington     NaN  2017-07-20T00:00:00
# 351                  FAA - Washington     NaN  2017-07-20T00:00:00
#
#        requestedShipDate requestedDeliveryDate  ... quantity quantityUnits  \
# 0    2021-08-31T00:00:00   2021-09-06T00:00:00  ...      250            EA
# 1    2021-08-31T00:00:00   2021-09-06T00:00:00  ...      250            EA
# 2    2021-08-31T00:00:00   2021-09-06T00:00:00  ...      250            EA
# 3    2021-08-19T00:00:00   2021-08-22T00:00:00  ...      132            EA
# 4    2021-08-19T00:00:00   2021-08-22T00:00:00  ...      132            EA
# ..                   ...                   ...  ...      ...           ...
# 347  2021-07-26T00:00:00   2021-07-26T00:00:00  ...       44            EA
# 348  2021-07-19T00:00:00   2021-07-19T00:00:00  ...       56            EA
# 349  2021-08-11T00:00:00   2021-08-14T00:00:00  ...      400            EA
# 350  2021-08-11T00:00:00   2021-08-14T00:00:00  ...      400            EA
# 351  2021-08-11T00:00:00   2021-08-14T00:00:00  ...      400            EA
#
#      productValue     value  valueCurrency  shipmentCount  \
# 0          1250.0  312500.0            USD            NaN
# 1             NaN       NaN            USD            NaN
# 2             NaN       NaN            USD            NaN
# 3          1250.0  165000.0            USD            NaN
# 4             NaN       NaN            USD            NaN
# ..            ...       ...            ...            ...
# 347           3.0     132.0            USD            NaN
# 348        1180.0   66080.0            USD            NaN
# 349        1250.0  500000.0            USD            NaN
# 350           NaN       NaN            USD            NaN
# 351           NaN       NaN            USD            NaN
#
#     productValueSinNulos_sklearn_mean  productValueSinNulos_sklearn_median  \
# 0                         1250.000000                               1250.0
# 1                          483.728873                                183.0
# 2                          483.728873                                183.0
# 3                         1250.000000                               1250.0
# 4                          483.728873                                183.0
# ..                                ...                                  ...
# 347                          3.000000                                  3.0
# 348                       1180.000000                               1180.0
# 349                       1250.000000                               1250.0
# 350                        483.728873                                183.0
# 351                        483.728873                                183.0
#
#      productValueSinNulos_sklearn_mode  productValueSinNulos_sklearn_const
# 0                               1250.0                              1250.0
# 1                               1250.0                                 0.0
# 2                               1250.0                                 0.0
# 3                               1250.0                              1250.0
# 4                               1250.0                                 0.0
# ..                                 ...                                 ...
# 347                                3.0                                 3.0
# 348                             1180.0                              1180.0
# 349                             1250.0                              1250.0
# 350                             1250.0                                 0.0
# 351                             1250.0                                 0.0
#
# [352 rows x 22 columns]
